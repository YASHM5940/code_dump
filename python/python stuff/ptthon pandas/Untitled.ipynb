# %%
import numpy as np
import pandas as pd

# %%
dict1={
    "name" :['jagi' , 'bluin' , 'monku'] , 
    "age" :['8' , '7' , '6']
    }

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#     name age
# 0   jagi   8
# 1  bluin   7
# 2  monku   6

# %%
df.to_csv('bacche.csv')
